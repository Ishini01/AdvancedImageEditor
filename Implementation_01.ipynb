# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishini01/AdvancedImageEditor/blob/main/Implementation_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/
# Out:
#  Classroom	   'ER Diagram.jpg'		 NewUsecaseDiagram.drawio.png
# 'Colab Notebooks'  'Medicinal plant dataset'
#  Dataset	    NewUpdatedERDiagram.drawio

# %%
base_path = "/content/drive/MyDrive/Medicinal plant dataset"

# %%
import os
print(os.listdir(base_path))
# Out:
# ['Sapodilla', 'Wood_sorel', 'Withania_somnifera', 'Scred_fig', 'Rose', 'Red_Sandalwoood', 'Pomegranate', 'Noni', 'Pepper', 'Papaya', 'Nagadali', 'Mint', 'Neem', 'Mango', 'Malabar_spinach', 'Jasmine', 'Lemon', 'Insulin', 'Lemon_grass', 'Honge', 'Guava', 'Hibiscus', 'Holy_Basil', 'Henna', 'Doddapatre', 'Garden_nightshade', 'Heartleaf_moonseed', 'Geranium', 'Gotu_kola', 'Giant_milkweed', 'Catharanthus_roseus', 'Castor', 'Betel_Nut', 'Avacado', 'Curry_Leaf', 'Betel', 'Amla', 'Bamboo', 'Aloevera', 'Ashoka']

# %%
total_images = 0
class_count = 0

for folder in os.listdir(base_path):
    folder_path = os.path.join(base_path, folder)
    if os.path.isdir(folder_path):
        num_images = len(os.listdir(folder_path))
        total_images += num_images
        class_count += 1
        print(f"{folder}: {num_images} images")

print("Total Images:", total_images)
print("Number of Classes:", class_count)
# Out:
# Sapodilla: 146 images
# Wood_sorel: 146 images
# Withania_somnifera: 146 images
# Scred_fig: 146 images
# Rose: 168 images
# Red_Sandalwoood: 146 images
# Pomegranate: 146 images
# Noni: 146 images
# Pepper: 146 images
# Papaya: 146 images
# Nagadali: 152 images
# Mint: 153 images
# Neem: 146 images
# Mango: 146 images
# Malabar_spinach: 146 images
# Jasmine: 187 images
# Lemon: 146 images
# Insulin: 146 images
# Lemon_grass: 146 images
# Honge: 146 images
# Guava: 146 images
# Hibiscus: 165 images
# Holy_Basil: 146 images
# Henna: 150 images
# Doddapatre: 146 images
# Garden_nightshade: 115 images
# Heartleaf_moonseed: 146 images
# Geranium: 146 images
# Gotu_kola: 146 images
# Giant_milkweed: 146 images
# Catharanthus_roseus: 146 images
# Castor: 160 images
# Betel_Nut: 146 images
# Avacado: 146 images
# Curry_Leaf: 146 images
# Betel: 151 images
# Amla: 146 images
# Bamboo: 146 images
# Aloevera: 164 images
# Ashoka: 146 images
# Total Images: 5945
# Number of Classes: 40

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = 224
BATCH_SIZE = 32

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = datagen.flow_from_directory(
    base_path,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_generator = datagen.flow_from_directory(
    base_path,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 4765 images belonging to 40 classes.
# Found 1180 images belonging to 40 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation='relu'),
    Dense(train_generator.num_classes, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=val_generator
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 20s 20s/step - accuracy: 0.0608 - loss: 5.2958
