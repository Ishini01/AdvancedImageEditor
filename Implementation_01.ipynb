# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishini01/AdvancedImageEditor/blob/main/Implementation_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# sample_data

# %%
import os

base_path = "sample_data"

total_images = 0

for folder in os.listdir(base_path):
    folder_path = os.path.join(base_path, folder)
    if os.path.isdir(folder_path):
        num_images = len(os.listdir(folder_path))
        total_images += num_images
        print(f"{folder}: {num_images} images")

print("Total Images:", total_images)
print("Number of Classes:", len(os.listdir(base_path)))
# Out:
# Total Images: 0
# Number of Classes: 6

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

class_names = os.listdir(base_path)

plt.figure(figsize=(10,8))

for i, class_name in enumerate(class_names[:4]):
    img_path = os.path.join(base_path, class_name, os.listdir(os.path.join(base_path, class_name))[0])
    img = image.load_img(img_path)

    plt.subplot(2,2,i+1)
    plt.imshow(img)
    plt.title(class_name)
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# /tmp/ipython-input-2329507682.py in <cell line: 0>()
#       7
#       8 for i, class_name in enumerate(class_names[:4]):
# ----> 9     img_path = os.path.join(base_path, class_name, os.listdir(os.path.join(base_path, class_name))[0])
#      10     img = image.load_img(img_path)
#      11
#
# NotADirectoryError: [Errno 20] Not a directory: 'sample_data/anscombe.json'
